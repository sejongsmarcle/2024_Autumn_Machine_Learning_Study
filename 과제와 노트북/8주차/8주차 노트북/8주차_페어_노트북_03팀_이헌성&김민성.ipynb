# %%
from sklearn.datasets import fetch_openml
mnist= fetch_openml('mnist_784',as_frame=False)

# %%
X_train=mnist.data[:60000]
y_train=mnist.target[:60000]

X_test=mnist.data[60000:]
y_test=mnist.target[60000:]

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf=SGDClassifier(random_state=42)
# %time sgd_clf.fit(X_train,y_train)
# Out:
# CPU times: user 3min 17s, sys: 475 ms, total: 3min 18s
# Wall time: 3min 40s
# SGDClassifier(random_state=42)

# %%
from sklearn.decomposition import PCA
import numpy as np
pca=PCA(n_components=0.95)
X_reduced=pca.fit_transform(X_train)

# %%
sgd_clf_reduced=SGDClassifier(random_state=42,max_iter=5000,n_jobs=-1)
# %time sgd_clf_reduced.fit(X_reduced,y_train)
# Out:
# CPU times: user 53.9 s, sys: 152 ms, total: 54 s
# Wall time: 36.3 s
# SGDClassifier(max_iter=5000, n_jobs=-1, random_state=42)

# %%
from sklearn.metrics import accuracy_score
X_test_reduced = pca.transform(X_test)
y_pred = sgd_clf_reduced.predict(X_test_reduced)
accuracy_score(y_test, y_pred)
# Out:
# 0.8959
